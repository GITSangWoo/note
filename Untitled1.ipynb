# %%
import pandas as pd

# %%
df=pd.read_parquet("~/code/team_repo/transform_path")
df
# Out:
#       rank rankInten                               movieNm      openDt  \
# 0        1         0                                 오펜하이머  2023-08-15
# 1        2         0                                    타겟  2023-08-30
# 2        3         0                             콘크리트 유토피아  2023-08-09
# 3        4         0                           달짝지근해: 7510  2023-08-15
# 4        5         0                                    밀수  2023-07-26
# ...    ...       ...                                   ...         ...
# 1215     6         0                             도티와 영원의 탑  2023-12-27
# 1216     7         0                      뽀로로 극장판 슈퍼스타 대모험  2023-12-13
# 1217     8         0                                    괴물  2023-11-29
# 1218     9         0  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!  2023-12-27
# 1219    10         0                         류이치 사카모토: 오퍼스  2023-12-27
#
#        salesAmt  salesShare salesInten salesChange     salesAcc  audiCnt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1220 non-null   int64
#  1   rankInten    1220 non-null   object
#  2   movieNm      1220 non-null   object
#  3   openDt       1220 non-null   object
#  4   salesAmt     1220 non-null   int64
#  5   salesShare   1220 non-null   float64
#  6   salesInten   1220 non-null   object
#  7   salesChange  1220 non-null   object
#  8   salesAcc     1220 non-null   int64
#  9   audiCnt      1220 non-null   int64
#  10  audiInten    1220 non-null   int64
#  11  audiChange   1220 non-null   float64
#  12  audiAcc      1220 non-null   int64
#  13  scrnCnt      1220 non-null   int64
#  14  showCnt      1220 non-null   int64
#  15  load_dt      1220 non-null   category
# dtypes: category(1), float64(2), int64(8), object(5)
# memory usage: 147.8+ KB

# %%
df[df['load_dt']=='20230928'].sort_values('audiChange',ascending=False)
# Out:
#      rank  rankInten                      movieNm    openDt    salesAmt  \
# 274     5         66  극장판 엉덩이 탐정: 미스터리 가면 ~최강의 대결  20230928   134035744
# 279    10         11                   80일간의 세계일주  20230927    27658950
# 278     9          1       아르고 원정대: 꼬마 영웅 패티의 대모험  20230921    38573644
# 277     8          0                        오펜하이머  20230815    43851616
# 276     7          0                  가문의 영광: 리턴즈  20230921    49548318
# 271     2          0                     1947 보스톤  20230927   871670929
# 270     1          0           천박사 퇴마 연구소: 설경의 비밀  20230927  1874529856
# 275     6         -1                            잠  20230906   108545411
# 272     3          1                          거미집  20230927   415915890
# 273     4         -1                        더 넌 2  20230927   357277751
#
#      salesShare  salesInten  salesChange     salesAcc  audiCnt  audiInten  \
# 274         3.2   133945744     148828.6    169495744    14978      14963
# ...

# %%
df.describe()
# Out:
#               rank      salesAmt   salesShare      salesAcc        audiCnt  \
# count  1220.000000  1.220000e+03  1220.000000  1.220000e+03    1220.000000
# mean      5.500000  2.839596e+08     9.072295  1.047783e+10   29041.882787
# std       2.873459  7.157482e+08    14.594503  1.923150e+10   72221.019528
# min       1.000000  3.867500e+06     0.200000  8.680000e+06     526.000000
# 25%       3.000000  3.341962e+07     1.400000  4.697928e+08    3473.750000
# 50%       5.500000  7.193688e+07     3.400000  2.332750e+09    7357.500000
# 75%       8.000000  1.967106e+08     8.900000  1.202652e+10   20422.000000
# max      10.000000  6.980194e+09    87.400000  1.153505e+11  700900.000000
#
#            audiInten     audiChange       audiAcc      scrnCnt      showCnt
# count    1220.000000    1220.000000  1.220000e+03  1220.000000  1220.000000
# mean     1039.859836     875.609754  1.096304e+06   531.611475  1454.720492
# ...

# %%
print("flag0:",df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1220 non-null   int64
#  1   rankInten    1220 non-null   int64
#  2   movieNm      1220 non-null   object
#  3   openDt       1220 non-null   object
#  4   salesAmt     1220 non-null   int64
#  5   salesShare   1220 non-null   float64
#  6   salesInten   1220 non-null   int64
#  7   salesChange  1220 non-null   float64
#  8   salesAcc     1220 non-null   int64
#  9   audiCnt      1220 non-null   int64
#  10  audiInten    1220 non-null   int64
#  11  audiChange   1220 non-null   float64
#  12  audiAcc      1220 non-null   int64
#  13  scrnCnt      1220 non-null   int64
#  14  showCnt      1220 non-null   int64
#  15  load_dt      1220 non-null   object
# dtypes: float64(3), int64(10), object(3)
# memory usage: 152.6+ KB
# flag0: None

# %%
 print(df['load_dt'].head(3))
# Out:
# 0    20230901
# 1    20230901
# 2    20230901
# Name: load_dt, dtype: object

# %%
dg=df.groupby('audiCnt').sum().sort_values('audiCnt',ascending=False)
df_unique_first = dg.drop_duplicates(subset='movieNm', keep='first')
df_unique_first
# Out:
#          rank  rankInten             movieNm            openDt    salesAmt  \
# audiCnt
# 700900      1          0               서울의 봄          20231122  6980193873
# 611648      1          0          노량: 죽음의 바다          20231220  6266643783
# 308934      1          0  천박사 퇴마 연구소: 설경의 비밀          20230927  3013748498
# 255230      1          0      그대들은 어떻게 살 것인가          20231025  2082957643
# 173351      1          0                 30일          20231003  1735314556
# ...       ...        ...                 ...               ...         ...
# 1069       10          5       매드 맥스: 분노의 도로          20150514    10416000
# 1000       20          0           화란익스펜더블 4  2023101120231018    20000000
# 836        10          5           리빙: 어떤 인생          20231213     7795239
# 835         8         18         두 사람을 위한 식탁          20231025     6156500
# 526        10          8            냉정과 열정사이          20031010     4060160
#
# ...

# %%
grouped = df.groupby('movieNm').agg({
    'audiCnt': 'sum',
    'openDt': 'max',
    'load_dt' :'max'
}).reset_index()
grouped.sort_values('audiCnt',ascending=False)

for i in range(1,13):
    f_df =df[df['load_dt'].astype(str).str.contains(f'2023{i}')]
    f_s_df=filtered_df.sort_values('audiChange',ascending=False)
    f_s_df.head(2))
# Out:
#                movieNm   audiCnt    openDt   load_dt
# 64               서울의 봄  11850944  20231122  20231231
# 25          노량: 죽음의 바다   3435273  20231220  20231231
# 1                  30일   2147622  20231003  20231128
# 11      그대들은 어떻게 살 것인가   1987300  20231025  20231213
# 99  천박사 퇴마 연구소: 설경의 비밀   1905229  20230927  20231025
# ..                 ...       ...       ...       ...
# 79               안녕하세요      1266  20220525  20231205
# 49       매드 맥스: 분노의 도로      1069  20150514  20231128
# 42           리빙: 어떤 인생       836  20231213  20231218
# 37         두 사람을 위한 식탁       835  20231025  20231030
# 22            냉정과 열정사이       526  20031010  20231211
#
# [121 rows x 4 columns]

# %%
col=['rankInten','salesInten','salesChange']
for i in col:
    df[i]=pd.to_numeric(df[i])
df['openDt'] = pd.to_datetime(df['openDt'])
df['openDt'] = df['openDt'].dt.strftime('%Y%m%d')
df['load_dt'] = df['load_dt'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         1220 non-null   int64
#  1   rankInten    1220 non-null   int64
#  2   movieNm      1220 non-null   object
#  3   openDt       1220 non-null   object
#  4   salesAmt     1220 non-null   int64
#  5   salesShare   1220 non-null   float64
#  6   salesInten   1220 non-null   int64
#  7   salesChange  1220 non-null   float64
#  8   salesAcc     1220 non-null   int64
#  9   audiCnt      1220 non-null   int64
#  10  audiInten    1220 non-null   int64
#  11  audiChange   1220 non-null   float64
#  12  audiAcc      1220 non-null   int64
#  13  scrnCnt      1220 non-null   int64
#  14  showCnt      1220 non-null   int64
#  15  load_dt      1220 non-null   object
# dtypes: float64(3), int64(10), object(3)
# memory usage: 152.6+ KB

# %%
df
# Out:
#       rank  rankInten                               movieNm    openDt  \
# 0        1          0                                 오펜하이머  20230815
# 1        2          0                                    타겟  20230830
# 2        3          0                             콘크리트 유토피아  20230809
# 3        4          0                           달짝지근해: 7510  20230815
# 4        5          0                                    밀수  20230726
# ...    ...        ...                                   ...       ...
# 1215     6          0                             도티와 영원의 탑  20231227
# 1216     7          0                      뽀로로 극장판 슈퍼스타 대모험  20231213
# 1217     8          0                                    괴물  20231129
# 1218     9          0  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!  20231227
# 1219    10          0                         류이치 사카모토: 오퍼스  20231227
#
#        salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# ...

# %%
df[df['audiChange'] >55].sort_values('load_dt', ascending =False)
# Out:
#       rank  rankInten                               movieNm      openDt  \
# 1206     7         -1                      뽀로로 극장판 슈퍼스타 대모험  2023-12-13
# 1205     6          3                             도티와 영원의 탑  2023-12-27
# 1204     5          0                            트롤: 밴드 투게더  2023-12-20
# 1202     3          1  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22
# 1201     2          0                                 서울의 봄  2023-11-22
# ...    ...        ...                                   ...         ...
# 11       2          0                                    타겟  2023-08-30
# 16       7         -1                              신체모음.zip  2023-08-30
# 18       9          5                       마야 3: 숲속 왕국의 위기  2023-08-24
# 19      10          0                               일주일간 친구  2023-09-06
# 10       1          0                                 오펜하이머  2023-08-15
#
#         salesAmt  salesShare  salesInten  salesChange      salesAcc  audiCnt  \
# ...

# %%
for i in range(9,12):
    f_df =df[df['load_dt'].astype(str).str.contains(f'2023{i}')]
    f_s_df=filtered_df.sort_values('audiChange',ascending=False)
    f_s_df.head(2))
# Out:
# Empty DataFrame
# Columns: [rank, rankInten, movieNm, openDt, salesAmt, salesShare, salesInten, salesChange, salesAcc, audiCnt, audiInten, audiChange, audiAcc, scrnCnt, showCnt, load_dt]
# Index: []
#      rank  rankInten            movieNm    openDt    salesAmt  salesShare  \
# 416     7         70  에브리씽 에브리웨어 올 앳 원스  20221012    28545700         2.6
# 320     1         14                30일  20231003  1696710861        32.4
#
#      salesInten  salesChange    salesAcc  audiCnt  audiInten  audiChange  \
# 416    28415700      21858.2  3920531529     2892       2879     22146.2
# 320  1676397503       8252.7  1894074984   171979     170247      9829.5
#
#      audiAcc  scrnCnt  showCnt   load_dt
# 416   370187       48       75  20231012
# 320   192167     1034     3830  20231003
#      rank  rankInten        movieNm    openDt    salesAmt  salesShare  \
# 895     6        119  명탐정코난: 흑철의 어영  20230720    42675000         1.1
# ...

# %%
df[df['load_dt']!=df['openDt']].sort_values('audiChange',ascending=False)
# Out:
#       rank  rankInten                                  movieNm    openDt  \
# 895      6        119                            명탐정코난: 흑철의 어영  20230720
# 416      7         70                        에브리씽 에브리웨어 올 앳 원스  20221012
# 697      8         67  극장판 아이돌리쉬 세븐; 라이브 4비트 비욘드 더 피리어드 - 데이 1  20231019
# 1038     9         63                               더 퍼스트 슬램덩크  20230104
# 994      5         35                         뽀로로 극장판 슈퍼스타 대모험  20231213
# ...    ...        ...                                      ...       ...
# 108      9         -3                                     엘리멘탈  20230614
# 876      7         -4                       스노우 폭스: 썰매개가 될 거야!  20231123
# 1086     7         -5                         뽀로로 극장판 슈퍼스타 대모험  20231213
# 1017     8         -1                                프레디의 피자가게  20231115
# 398      9         -6                         퍼피 구조대: 더 마이티 무비  20231006
#
#        salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# ...
