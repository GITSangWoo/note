# %%
import pandas as pd
df=pd.read_parquet("~/code/team_repo/transform_path")
col=['rankInten','salesInten','salesChange']
for i in col:
    df[i]=pd.to_numeric(df[i])

df['openDt'] = pd.to_datetime(df['openDt'],errors='coerce')
df['openDt'] = df['openDt'].dt.strftime('%Y%m%d')
df['load_dt'] = df['load_dt'].astype(str)
    
grouped = df.groupby('movieNm').agg({
    'audiCnt': 'sum',
    'openDt': 'max',
    'load_dt' :'max'
    }).reset_index()

grsort=grouped.sort_values('audiCnt',ascending=False)
grsort
# Out:
#                movieNm   audiCnt    openDt   load_dt
# 64               서울의 봄  11850944  20231122  20231231
# 25          노량: 죽음의 바다   3435273  20231220  20231231
# 1                  30일   2147622  20231003  20231128
# 11      그대들은 어떻게 살 것인가   1987300  20231025  20231213
# 99  천박사 퇴마 연구소: 설경의 비밀   1905229  20230927  20231025
# ..                 ...       ...       ...       ...
# 79               안녕하세요      1266  20220525  20231205
# 49       매드 맥스: 분노의 도로      1069  20150514  20231128
# 42           리빙: 어떤 인생       836  20231213  20231218
# 37         두 사람을 위한 식탁       835  20231025  20231030
# 22            냉정과 열정사이       526  20031010  20231211
#
# [121 rows x 4 columns]

# %%
day=['20230101','20230121','20230122','20230123','20230124','20230301','20230505','20230527','20230529','20230606','20230815','20230928','20230929','20230930','20231003','20231009','20231225']
special_day = df[df['load_dt'].isin(day)]
special_day.groupby('movieNm').agg({
    'rank' : 'max',
    'rankInten' : 'max',
    'audiCnt': 'sum',
    'openDt': 'max',
    'load_dt' :'max'
    }).sort_values(['load_dt','audiCnt'], ascending = False)
# Out:
#                                       rank  rankInten  audiCnt    openDt  \
# movieNm
# 노량: 죽음의 바다                               1          0   549530  20231220
# 서울의 봄                                    2          0   427026  20231122
# 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~     3          1   133547  20231222
# 아쿠아맨과 로스트 킹덤                             4         -1   115955  20231220
# 트롤: 밴드 투게더                               5          0    79424  20231220
# 뽀로로 극장판 슈퍼스타 대모험                         6          0    36088  20231213
# 괴물                                       7          0     8542  20231129
# 3일의 휴가                                   8          0     5930  20231206
# 바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!     9          1     5096  20231227
# 말하고 싶은 비밀                               10          1     4625  20231213
# 천박사 퇴마 연구소: 설경의 비밀                       2          0   949500  20230927
# 1947 보스톤                                 5          0   463644  20230927
# 30일                                      1         14   326390  20231003
# 거미집                                     10          1   155964  20230927
# 더 넌 2                                    6          0   139786  20230927
# 크리에이터                                    4          0   107061  20231003
# 극장판 엉덩이 탐정: 미스터리 가면 ~최강의 대결              8         66    73822  20230928
# 퍼피 구조대: 더 마이티 무비                         3          2    29137  20231006
# 화란                                       7          0    10437  20231011
# 사나: 저주의 아이                               9         -1     6718  20231004
# 잠                                        9          1    48070  20230906
# 오펜하이머                                   10          0    20158  20230815
# 드림쏭2                                     8          0     6658  20231003
# 가문의 영광: 리턴즈                              7          0    26257  20230921
# 아르고 원정대: 꼬마 영웅 패티의 대모험                   9          1    13858  20230921
# 80일간의 세계일주                              10         11    10565  20230927
#
#                                        load_dt
# movieNm
# 노량: 죽음의 바다                            20231225
# 서울의 봄                                 20231225
# 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231225
# 아쿠아맨과 로스트 킹덤                          20231225
# 트롤: 밴드 투게더                            20231225
# 뽀로로 극장판 슈퍼스타 대모험                      20231225
# 괴물                                    20231225
# 3일의 휴가                                20231225
# 바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!  20231225
# 말하고 싶은 비밀                             20231225
# 천박사 퇴마 연구소: 설경의 비밀                    20231009
# 1947 보스톤                              20231009
# 30일                                   20231009
# 거미집                                   20231009
# 더 넌 2                                 20231009
# 크리에이터                                 20231009
# 극장판 엉덩이 탐정: 미스터리 가면 ~최강의 대결           20231009
# 퍼피 구조대: 더 마이티 무비                      20231009
# 화란                                    20231009
# 사나: 저주의 아이                            20231009
# 잠                                     20231003
# 오펜하이머                                 20231003
# 드림쏭2                                  20231003
# 가문의 영광: 리턴즈                           20230930
# 아르고 원정대: 꼬마 영웅 패티의 대모험                20230930
# 80일간의 세계일주                            20230930

# %%
df[df['load_dt']==20241225]
# Out:
# Empty DataFrame
# Columns: [rank, rankInten, movieNm, openDt, salesAmt, salesShare, salesInten, salesChange, salesAcc, audiCnt, audiInten, audiChange, audiAcc, scrnCnt, showCnt, load_dt]
# Index: []

# %%
import pandas as pd
df=pd.read_parquet("~/code/team_repo/transform_path")


col=['rankInten','salesInten','salesChange']
for i in col:
    df[i]=pd.to_numeric(df[i])

df['openDt'] = pd.to_datetime(df['openDt'],errors='coerce')
df['openDt'] = df['openDt'].dt.strftime('%Y%m%d')
df['load_dt'] = df['load_dt'].astype(str)
day=['20230101','20230121','20230122','20230123','20230124','20230301','20230505','20230527','20230529','20230606','20230815','20230928','20230929','20230930','20231003','20231009','20231225']
special_day = df[df['load_dt'].isin(day)].groupby('movieNm').agg({
    'rank' : 'max',
    'rankInten' : 'max',
    'audiCnt': 'sum',
    'openDt': 'max',
    'load_dt' :'max'
    }).sort_values(['load_dt','rank'], ascending = False)

special_day1=special_day[special_day['rankInten']!=0]
special_day1
# Out:
#                                        rank  rankInten  audiCnt    openDt  \
# movieNm
# 말하고 싶은 비밀                                10          1     4625  20231213
# 바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!      9          1     5096  20231227
# 아쿠아맨과 로스트 킹덤                              4         -1   115955  20231220
# 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~      3          1   133547  20231222
# 거미집                                      10          1   155964  20230927
# 사나: 저주의 아이                                9         -1     6718  20231004
# 극장판 엉덩이 탐정: 미스터리 가면 ~최강의 대결               8         66    73822  20230928
# 퍼피 구조대: 더 마이티 무비                          3          2    29137  20231006
# 30일                                       1         14   326390  20231003
# 잠                                         9          1    48070  20230906
# 80일간의 세계일주                               10         11    10565  20230927
# 아르고 원정대: 꼬마 영웅 패티의 대모험                    9          1    13858  20230921
# 런닝맨: 리벤져스                                10          1     7890  20230810
# 비공식작전                                     9         -5    10573  20230802
# 바다 탐험대 옥토넛 어보브 앤 비욘드 : 육지 넘어 하늘까지!        8          2    12958  20230810
# 메가로돈 2                                    6         21    42233  20230815
# 엘리멘탈                                      5         -2    71733  20230614
# 밀수                                        4         -2    96436  20230726
# 콘크리트 유토피아                                 2         -1   303132  20230809
# 극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대                8          1   202043  20230504
# 슈퍼 마리오 브라더스                               6          1   520953  20230426
# 인어공주                                      5          1   240303  20230524
# 포켓 몬스터 DP: 아르세우스 초극의 시공으로                 3          1    40175  20091224
# 범죄도시3                                     2          1  1150651  20230531
# 트랜스포머: 비스트의 서막                            2         10   211506  20230606
# 슬픔의 삼각형                                  10          1     5049  20230517
# 스즈메의 문단속                                  9          1    82623  20230308
# 리바운드                                     10         -2     3573  20230405
# 뮤지컬 공연실황, 알쏭달쏭 캐치! 티니핑 <신비한 상자를 열어라!>     9          7     4740  20230503
# 더 퍼스트 슬램덩크                                8          1   515613  20230104
# 존 윅 4                                     6         -1    41052  20230412
# 드림                                        4         -1    92583  20230426
# 에브리씽 에브리웨어 올 앳 원스+                       10         15     8432  20230301
# 두다다쿵: 후후섬의 비밀                             9         -3     9786  20230215
# 마루이 비디오                                   8         -3    12475  20230222
# 카운트                                       7         -4    28800  20230222
# 서치 2                                      6         -2    35839  20230222
# 멍뭉이                                       5         22    39108  20230301
# 앤트맨과 와스프: 퀀텀매니아                           3         -1    57102  20230215
# 라일 라일 크로커다일                              10          1    27510  20230118
# 스위치                                      10          2    41988  20230104
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도                  9          1    71558  20221130
# 캐리와 슈퍼콜라                                  8          2    51679  20230118
# 아바타: 물의 길                                 3          1   915408  20221214
# 젠틀맨                                       4         -1    26293  20221228
#
#                                         load_dt
# movieNm
# 말하고 싶은 비밀                              20231225
# 바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!   20231225
# 아쿠아맨과 로스트 킹덤                           20231225
# 신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~   20231225
# 거미집                                    20231009
# 사나: 저주의 아이                             20231009
# 극장판 엉덩이 탐정: 미스터리 가면 ~최강의 대결            20231009
# 퍼피 구조대: 더 마이티 무비                       20231009
# 30일                                    20231009
# 잠                                      20231003
# 80일간의 세계일주                             20230930
# 아르고 원정대: 꼬마 영웅 패티의 대모험                 20230930
# 런닝맨: 리벤져스                              20230815
# 비공식작전                                  20230815
# 바다 탐험대 옥토넛 어보브 앤 비욘드 : 육지 넘어 하늘까지!     20230815
# 메가로돈 2                                 20230815
# 엘리멘탈                                   20230815
# 밀수                                     20230815
# 콘크리트 유토피아                              20230815
# 극장판 짱구는 못말려: 동물소환 닌자 배꼽수비대             20230606
# 슈퍼 마리오 브라더스                            20230606
# 인어공주                                   20230606
# 포켓 몬스터 DP: 아르세우스 초극의 시공으로              20230606
# 범죄도시3                                  20230606
# 트랜스포머: 비스트의 서막                         20230606
# 슬픔의 삼각형                                20230529
# 스즈메의 문단속                               20230529
# 리바운드                                   20230505
# 뮤지컬 공연실황, 알쏭달쏭 캐치! 티니핑 <신비한 상자를 열어라!>  20230505
# 더 퍼스트 슬램덩크                             20230505
# 존 윅 4                                  20230505
# 드림                                     20230505
# 에브리씽 에브리웨어 올 앳 원스+                     20230301
# 두다다쿵: 후후섬의 비밀                          20230301
# 마루이 비디오                                20230301
# 카운트                                    20230301
# 서치 2                                   20230301
# 멍뭉이                                    20230301
# 앤트맨과 와스프: 퀀텀매니아                        20230301
# 라일 라일 크로커다일                            20230124
# 스위치                                    20230124
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도               20230124
# 캐리와 슈퍼콜라                               20230124
# 아바타: 물의 길                              20230124
# 젠틀맨                                    20230101

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 7.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in /home/centa/.pyenv/versions/note/lib/python3.11/site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/centa/.pyenv/versions/note/lib/python3.11/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/centa/.pyenv/versions/note/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/centa/.pyenv/versions/note/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 6.7 MB/s eta 0:00:0000:0100:01m
# Downloading contourpy-1.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 4.2 MB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Using cached pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 kiwisolver-1.4.5 matplotlib-3.9.0 pillow-10.4.0 pyparsing-3.1.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
df['load_dt']=pd.to_datetime(df['load_dt'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3630 entries, 0 to 3629
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         3630 non-null   int64
#  1   rankInten    3630 non-null   int64
#  2   movieNm      3630 non-null   object
#  3   openDt       3629 non-null   object
#  4   salesAmt     3630 non-null   int64
#  5   salesShare   3630 non-null   float64
#  6   salesInten   3630 non-null   int64
#  7   salesChange  3630 non-null   float64
#  8   salesAcc     3630 non-null   int64
#  9   audiCnt      3630 non-null   int64
#  10  audiInten    3630 non-null   int64
#  11  audiChange   3630 non-null   float64
#  12  audiAcc      3630 non-null   int64
#  13  scrnCnt      3630 non-null   int64
#  14  showCnt      3630 non-null   int64
#  15  load_dt      3630 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(10), object(2)
# memory usage: 453.9+ KB

# %%
import matplotlib.pyplot as plt

# %%
a=df[df['movieNm']=='신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~']
a
# Out:
#       rank  rankInten                               movieNm    openDt  \
# 3533     4          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3543     4          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3553     4          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3562     3          1  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3573     4         -1  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3583     4          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3593     4          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3603     4          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3612     3          1  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
# 3622     3          0  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  20231222
#
#         salesAmt  salesShare  salesInten  salesChange    salesAcc  audiCnt  \
# 3533   286783751         6.1   286783751        100.0   367792576    29375
# 3543   734978425         7.2   448194674        156.3  1102771001    75618
# 3553  1022799814         7.1   287821389         39.2  2125570815   104377
# 3562  1320028999         9.4   297229185         29.1  3445599814   133547
# 3573   195691304         5.8 -1124337695        -85.2  3641291118    20749
# 3583   196560717         5.5      869413          0.4  3837851835    24076
# 3593   191419521         6.1    -5141196         -2.6  4029271356    20720
# 3603   298724683         6.8   107305162         56.1  4327996039    31278
# 3612   543025530         7.5   244300847         81.8  4871021569    55938
# 3622   635306120         7.0    92280590         17.0  5506327689    64990
#
#       audiInten  audiChange  audiAcc  scrnCnt  showCnt   load_dt
# 3533      29375       100.0    36976      766     1406  20231222
# 3543      46243       157.4   112594      868     1732  20231223
# 3553      28759        38.0   216971      856     1758  20231224
# 3562      29170        27.9   350518      883     1796  20231225
# 3573    -112798       -84.5   371267      724     1351  20231226
# 3583       3327        16.0   395343      728     1235  20231227
# 3593      -3356       -13.9   416063      722     1264  20231228
# 3603      10558        51.0   447341      737     1360  20231229
# 3612      24660        78.8   503279      829     1700  20231230
# 3622       9052        16.2   568269      843     1725  20231231

# %%
a=df[df['movieNm']=='신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~']
df_subset = a.loc[:, ['movieNm', 'rankInten','load_dt','openDt','audiCnt']]
df_subset
# Out:
#                                    movieNm  rankInten   load_dt    openDt  \
# 3533  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231222  20231222
# 3543  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231223  20231222
# 3553  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231224  20231222
# 3562  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          1  20231225  20231222
# 3573  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~         -1  20231226  20231222
# 3583  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231227  20231222
# 3593  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231228  20231222
# 3603  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231229  20231222
# 3612  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          1  20231230  20231222
# 3622  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~          0  20231231  20231222
#
#       audiCnt
# 3533    29375
# 3543    75618
# 3553   104377
# 3562   133547
# 3573    20749
# 3583    24076
# 3593    20720
# 3603    31278
# 3612    55938
# 3622    64990

# %%
# 꺾은선 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(df_subset['load_dt'], df_subset['audiCnt'], marker='o', linestyle='-')
plt.title('date audience count')
plt.xlabel('date')
plt.ylabel('audience count')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

# 그래프 보여주기
plt.show()
